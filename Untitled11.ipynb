# %% [markdown]
# <a href="https://colab.research.google.com/github/kalki81000/python/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/content/sanket.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 13201  2019                     Level 4                MN213
# 13202  2019                     Level 4                MN213
# 13203  2019                     Level 4                MN213
# 13204  2019                     Level 4                MN213
# 13205  2019                     Level 4                MN213
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...

# %%
df =doc/data/titanic.csv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5033d3800ffc> in <cell line: 1>()
# ----> 1 df =doc/data/titanic.csv
#
# NameError: name 'doc' is not defined

# %%
pd.read_json("doc/data/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-d605fcb58091> in <cell line: 1>()
# ----> 1 pd.read_json("doc/data/titanic.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782         return json_reader
#     783     else:
# --> 784         return json_reader.read()
#     785
#     786
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/json/_json.py in read(self)
#     973                         obj = self._get_object_parser(self._combine_lines(data_lines))
#     974                 else:
# --> 975                     obj = self._get_object_parser(self.data)
# ...

# %%
pd.read_html("doc/data/titanic.csv")
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py:674: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(udoc, features="html5lib", from_encoding=from_encoding)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-584f366665da> in <cell line: 1>()
# ----> 1 pd.read_html("doc/data/titanic.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend)
#    1210     io = stringify_path(io)
#    1211
# -> 1212     return _parse(
#    1213         flavor=flavor,
#    1214         io=io,
#
# ...

# %%
import pandas as pd


df= pd.read_csv("https://github.com/pandas-dev/pandas/blob/main/doc/data/air_quality_no2_long.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-10-b54bd76fe56b> in <cell line: 4>()
#       2
#       3
# ----> 4 df= pd.read_csv("https://github.com/pandas-dev/pandas/blob/main/doc/data/air_quality_no2_long.csv")
#
# ...

# %%
train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-63b9ea20ef47> in <cell line: 1>()
# ----> 1 train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
#Read data from CSV input
train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
test_df = pd.read_csv("/kaggle/input/titanic/test.csv")
combine = [train_df, test_df]
print(train_df.columns.values)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-a01577f4fd85> in <cell line: 6>()
#       4         print(os.path.join(dirname, filename))
#       5 #Read data from CSV input
# ----> 6 train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
#       7 test_df = pd.read_csv("/kaggle/input/titanic/test.csv")
#       8 combine = [train_df, test_df]
#
# ...

# %%
https://www.kaggle.com/code/kaustubhshirpurkar/exploring-titanic-data-using-pandas-dataframes?scriptVersionId=44224742&cellId=1
# Out:
#   File "<ipython-input-13-a7fe3ff64cd8>", line 1
#     https://www.kaggle.com/code/kaustubhshirpurkar/exploring-titanic-data-using-pandas-dataframes?scriptVersionId=44224742&cellId=1
#           ^
# SyntaxError: invalid syntax

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
#Read data from CSV input
train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
test_df = pd.read_csv("/kaggle/input/titanic/test.csv")
combine = [train_df, test_df]
print(train_df.columns.values)
# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
/kaggle/input/titanic/test.csv
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-5b733b2593bd> in <cell line: 12>()
#      10         print(os.path.join(dirname, filename))
#      11 #Read data from CSV input
# ---> 12 train_df = pd.read_csv("/kaggle/input/titanic/train.csv")
#      13 test_df = pd.read_csv("/kaggle/input/titanic/test.csv")
#      14 combine = [train_df, test_df]
#
# ...

# %%
import pandas as pd
df = pd.read_excel('dirty_titanic_df.xlsx')
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-26a768358738> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.read_excel('dirty_titanic_df.xlsx')
#       3 df.head(10)
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
#     476     if not isinstance(io, ExcelFile):
#     477         should_close = True
# --> 478         io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     479     elif engine and engine != io.engine:
#     480         raise ValueError(
#
# ...

# %%
df

d =df.read_csv("sanket.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-511d146de9d0> in <cell line: 1>()
# ----> 1 df
#       2
#       3 d =df.read_csv("sanket.csv")
#
# NameError: name 'df' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.read
# Out:
#   File "<ipython-input-22-5f606997fb11>", line 1
#     df =/content/sanket.csv
#         ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 13201  2019                     Level 4                MN213
# 13202  2019                     Level 4                MN213
# 13203  2019                     Level 4                MN213
# 13204  2019                     Level 4                MN213
# 13205  2019                     Level 4                MN213
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...

# %%
df.iloc[0:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1  674,890  ANZSIC06 divisions A-S (excluding classes K633...

# %%
df.loc[0:2]
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 2  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# 2                Interest, dividends and donations  Financial performance
#
#      Value                             Industry_code_ANZSIC06
# 0  757,504  ANZSIC06 divisions A-S (excluding classes K633...
# 1  674,890  ANZSIC06 divisions A-S (excluding classes K633...
# ...

# %%
df.loc[0:2['Year','Units']]
# Out:
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
# <ipython-input-30-f0103592ae94>:1: SyntaxWarning: 'int' object is not subscriptable; perhaps you missed a comma?
#   df.loc[0:2['Year','Units']]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-f0103592ae94> in <cell line: 1>()
# ----> 1 df.loc[0:2['Year','Units']]
#
# TypeError: 'int' object is not subscriptable

# %%
df.iloc[0:2,3:6]
# Out:
#   Industry_name_NZSIOC               Units Variable_code
# 0       All industries  Dollars (millions)           H01
# 1       All industries  Dollars (millions)           H04

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 13201  2019                     Level 4                MN213
# 13202  2019                     Level 4                MN213
# 13203  2019                     Level 4                MN213
# 13204  2019                     Level 4                MN213
# 13205  2019                     Level 4                MN213
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...

# %%
df['variable_name'][2:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variable_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
s = pd.Series(list(df['Name'][2:5]),index = ['a','b','c'])

# %%
s
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
df.loc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.iloc[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.loc[0:2,['Name','Parch']]
# Out:
#                                                 Name  Parch
# 0                            Braund, Mr. Owen Harris      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0
# 2                             Heikkinen, Miss. Laina      0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[0:2,3:6]
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0

# %%
df['Name'][2:5]
# Out:
# 2                          Heikkinen, Miss. Laina
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                        Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
u =pd.Series(list(df['Name'][2:5]),index =['a','b','c'])

# %%
u
# Out:
# a                          Heikkinen, Miss. Laina
# b    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# c                        Allen, Mr. William Henry
# dtype: object

# %%
s=pd.Series(list(df['Name'][5:8]),index =['a','b','c'])

# %%
s
# Out:
# a                  Moran, Mr. James
# b           McCarthy, Mr. Timothy J
# c    Palsson, Master. Gosta Leonard
# dtype: object

# %%
s+u
# Out:
# a               Moran, Mr. JamesHeikkinen, Miss. Laina
# b    McCarthy, Mr. Timothy JFutrelle, Mrs. Jacques ...
# c    Palsson, Master. Gosta LeonardAllen, Mr. Willi...
# dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop('PassengerId',axis = 1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1,inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
df.reset_index(drop = True)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              3         1       3
# 2              4         1       1
# 3              5         0       3
# 4              6         0       3
# ..           ...       ...     ...
# 885          887         0       2
# 886          888         1       1
# 887          889         0       3
# 888          890         1       1
# 889          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                          Heikkinen, Miss. Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                        Allen, Mr. William Henry    male  35.0      0      0
# 4                                Moran, Mr. James    male   NaN      0      0
# ...

# %%
df.set_index('Name')
# Out:
#                                               PassengerId  Survived  Pclass  \
# Name
# Braund, Mr. Owen Harris                                 1         0       3
# Heikkinen, Miss. Laina                                  3         1       3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1       1
# Allen, Mr. William Henry                                5         0       3
# Moran, Mr. James                                        6         0       3
# ...                                                   ...       ...     ...
# Montvila, Rev. Juozas                                 887         0       2
# Graham, Miss. Margaret Edith                          888         1       1
# Johnston, Miss. Catherine Helen "Carrie"              889         0       3
# Behr, Mr. Karl Howell                                 890         1       1
# Dooley, Mr. Patrick                                   891         0       3
#
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        2            3         1       3
# 2        3            4         1       1
# 3        4            5         0       3
# 4        5            6         0       3
# ..     ...          ...       ...     ...
# 885    886          887         0       2
# 886    887          888         1       1
# 887    888          889         0       3
# 888    889          890         1       1
# 889    890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                          Heikkinen, Miss. Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
d = {'key1':[1,2,3,4],
     'key2':[3,4,5,6],
     'key3':[6,5,4,3]}

# %%
d
# Out:
# {'key1': [1, 2, 3, 4], 'key2': [3, 4, 5, 6], 'key3': [6, 5, 4, 3]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     3     6
# 1     2     4     5
# 2     3     5     4
# 3     4     6     3

# %%
df.shape
# Out:
# (890, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        2            3         1       3
# 2        3            4         1       1
# 3        4            5         0       3
# 4        5            6         0       3
# ..     ...          ...       ...     ...
# 885    886          887         0       2
# 886    887          888         1       1
# 887    888          889         0       3
# 888    889          890         1       1
# 889    890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 1                          Heikkinen, Miss. Laina  female  26.0      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 3                        Allen, Mr. William Henry    male  35.0      0      0
# ...

# %%
df.isnull().Age
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 885    False
# 886    False
# 887     True
# 888    False
# 889    False
# Name: Age, Length: 890, dtype: bool

# %%
df.dropna()
# Out:
#      index  PassengerId  Survived  Pclass  \
# 2        3            4         1       1
# 5        6            7         0       1
# 9       10           11         1       3
# 10      11           12         1       1
# 20      21           22         1       2
# ..     ...          ...       ...     ...
# 870    871          872         1       1
# 871    872          873         0       1
# 878    879          880         1       1
# 886    887          888         1       1
# 888    889          890         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 2        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 5                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 10                           Bonnell, Miss. Elizabeth  female  58.0      0
# 20                              Beesley, Mr. Lawrence    male  34.0      0
# ...

# %%
df
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df.dropna(axis=1)
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        2            3         1       3
# 2        3            4         1       1
# 3        4            5         0       3
# 4        5            6         0       3
# ..     ...          ...       ...     ...
# 885    886          887         0       2
# 886    887          888         1       1
# 887    888          889         0       3
# 888    889          890         1       1
# 889    890          891         0       3
#
#                                              Name     Sex  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male      1      0
# 1                          Heikkinen, Miss. Laina  female      0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 3                        Allen, Mr. William Henry    male      0      0
# 4                                Moran, Mr. James    male      0      0
# ...

# %%
df.fillna("somevalue")
# Out:
#      index  PassengerId  Survived  Pclass  \
# 0        0            1         0       3
# 1        2            3         1       3
# 2        3            4         1       1
# 3        4            5         0       3
# 4        5            6         0       3
# ..     ...          ...       ...     ...
# 885    886          887         0       2
# 886    887          888         1       1
# 887    888          889         0       3
# 888    889          890         1       1
# 889    890          891         0       3
#
#                                              Name     Sex        Age  SibSp  \
# 0                         Braund, Mr. Owen Harris    male       22.0      1
# 1                          Heikkinen, Miss. Laina  female       26.0      0
# 2    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       35.0      1
# 3                        Allen, Mr. William Henry    male       35.0      0
# ...

# %%
data1 = {
    'A' : [1,2,None,4,5,None,7,8,9,10],
    'B' : [None,11,12,13,None,15,16,None,18,19]
}

# %%
df1 = pd.DataFrame(data1)

# %%
df1
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1.A.fillna(df1['A'].mean())
# Out:
# 0     1.00
# 1     2.00
# 2     5.75
# 3     4.00
# 4     5.00
# 5     5.75
# 6     7.00
# 7     8.00
# 8     9.00
# 9    10.00
# Name: A, dtype: float64

# %%
df1
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1.fillna("sanket")
# Out:
#         A       B
# 0     1.0  sanket
# 1     2.0    11.0
# 2  sanket    12.0
# 3     4.0    13.0
# 4     5.0  sanket
# 5  sanket    15.0
# 6     7.0    16.0
# 7     8.0  sanket
# 8     9.0    18.0
# 9    10.0    19.0

# %%
df1.fillna(method ="ffill")
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   2.0  12.0
# 3   4.0  13.0
# 4   5.0  13.0
# 5   5.0  15.0
# 6   7.0  16.0
# 7   8.0  16.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1.fillna(method ="bfill")
# Out:
#       A     B
# 0   1.0  11.0
# 1   2.0  11.0
# 2   4.0  12.0
# 3   4.0  13.0
# 4   5.0  15.0
# 5   7.0  15.0
# 6   7.0  16.0
# 7   8.0  18.0
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1
# Out:
#       A     B
# 0   1.0   NaN
# 1   2.0  11.0
# 2   NaN  12.0
# 3   4.0  13.0
# 4   5.0   NaN
# 5   NaN  15.0
# 6   7.0  16.0
# 7   8.0   NaN
# 8   9.0  18.0
# 9  10.0  19.0

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1.mean(axis = 0)
# Out:
# A     5.750000
# B    14.857143
# dtype: float64

# %%
df1.mod(axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-98-dd284e734d9b> in <cell line: 1>()
# ----> 1 df1.mod(axis=1)
#
# TypeError: flex_arith_method_FRAME.<locals>.f() missing 1 required positional argument: 'other'

# %%
df.std()
# Out:
# A    3.284161
# B    3.023716
# dtype: float64

# %%
df.describe()
# Out:
#                A          B
# count   8.000000   7.000000
# mean    5.750000  14.857143
# std     3.284161   3.023716
# min     1.000000  11.000000
# 25%     3.500000  12.500000
# 50%     6.000000  15.000000
# 75%     8.250000  17.000000
# max    10.000000  19.000000

# %%
df
# Out:
# [['Survived', 'Fare']]

# %%
df.Survived	== 1
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888    False
# 889     True
# 890    False
# Name: Survived, Length: 891, dtype: bool

# %%
df[df.Survived	== 1]['Fare'].mean()
# Out:
# 48.39540760233918

# %%
df.groupby('Survived').mean(numeric_only = True)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408

# %%
df.groupby('Survived').min(numeric_only = True)
# Out:
#           PassengerId  Pclass   Age  SibSp  Parch  Fare
# Survived
# 0                   1       1  1.00      0      0   0.0
# 1                   2       1  0.42      0      0   0.0

# %%
df.groupby('Survived').describe()
# Out:
#          PassengerId                                                     \
#                count        mean         std  min     25%    50%    75%
# Survived
# 0              549.0  447.016393  260.640469  1.0  211.00  455.0  675.0
# 1              342.0  444.368421  252.358840  2.0  250.75  439.5  651.5
#
#                 Pclass            ... Parch        Fare                        \
#             max  count      mean  ...   75%  max  count       mean        std
# Survived                          ...
# 0         891.0  549.0  2.531876  ...   0.0  6.0  549.0  22.117887  31.388207
# 1         890.0  342.0  1.950292  ...   1.0  5.0  342.0  48.395408  66.596998
#
#
#           min      25%   50%   75%       max
# Survived
# 0         0.0   7.8542  10.5  26.0  263.0000
# 1         0.0  12.4750  26.0  57.0  512.3292
#
# [2 rows x 48 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-331b05b4385d> in <cell line: 1>()
# ----> 1 df[['Survived','Fare']]
#
# TypeError: list indices must be integers or slices, not list

# %%
df1
# Out:
# [['Survived', 'Fare']]

# %%
df.groupby(['Sex','Pclass'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-124-12faa045f54e> in <cell line: 1>()
# ----> 1 df.groupby(['Sex','Pclass'])
#
# AttributeError: 'list' object has no attribute 'groupby'

# %%
df
# Out:
# [['Survived', 'Fare']]

# %%
import pandas as pd

df = pd.read_csv("/content/sanket.csv")

# %%
df
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 13201  2019                     Level 4                MN213
# 13202  2019                     Level 4                MN213
# 13203  2019                     Level 4                MN213
# 13204  2019                     Level 4                MN213
# 13205  2019                     Level 4                MN213
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...

# %%
df1=df[['Name','Sex','Age']][0:5]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-132-6d009afd1fe4> in <cell line: 1>()
# ----> 1 df1=df[['Name','Sex','Age']][0:5]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/content/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 =df[["Name","Sex","Age"]][0:5]

# %%
df1
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0

# %%
df2 =df[["Name","Sex","Age"]][5:10]

# %%
df2
# Out:
#                                                 Name     Sex   Age
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1 ,df2],axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1 ,df2],axis=1)
# Out:
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                                NaN     NaN   NaN
# 6                                                NaN     NaN   NaN
# 7                                                NaN     NaN   NaN
# 8                                                NaN     NaN   NaN
# 9                                                NaN     NaN   NaN
#
#                                                 Name     Sex   Age
# 0                                                NaN     NaN   NaN
# 1                                                NaN     NaN   NaN
# ...

# %%
df2.reset_index(drop = True)
# Out:
#                                                 Name     Sex   Age
# 0                                   Moran, Mr. James    male   NaN
# 1                            McCarthy, Mr. Timothy J    male  54.0
# 2                     Palsson, Master. Gosta Leonard    male   2.0
# 3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 4                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
pd.concat([df1 ,df2],axis=0)
# Out:
#                                                 Name     Sex   Age
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                           Allen, Mr. William Henry    male  35.0
# 5                                   Moran, Mr. James    male   NaN
# 6                            McCarthy, Mr. Timothy J    male  54.0
# 7                     Palsson, Master. Gosta Leonard    male   2.0
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0

# %%
df1= {
    'key1':[1,2,4,5,6],
    'key2':[4,5,6,7,8],
    'key3':[3,4,5,6,6]
}

# %%
df2 =pd.DataFrame(df1,index =['a','b','c','d','e'])

# %%
df1
# Out:
# {'key1': [1, 2, 4, 5, 6], 'key2': [4, 5, 6, 7, 8], 'key3': [3, 4, 5, 6, 6]}

# %%
df2
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df4= {
    'key1':[1,2,4,5,6],
    'key4':[4,5,67,7,88],
    'key5':[38,4,85,6,86]
}

# %%
df5= pd.DataFrame(df4,index = ['a','b','h','i','j'])

# %%
df5
# Out:
#    key1  key4  key5
# 0     1    47    38
# 1     2     5     4
# 2    44    67    85
# 3    67     7     6
# 4     6    88    86

# %%
df2
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(df2,df5,how = 'inner')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3    47    38
# 1     2     5     4     5     4
# 2     6     8     6    88    86

# %%
pd.merge(df2,df5,how = 'left')
# Out:
#    key1  key2  key3  key4  key5
# 0     1     4     3  47.0  38.0
# 1     2     5     4   5.0   4.0
# 2     4     6     5   NaN   NaN
# 3     5     7     6   NaN   NaN
# 4     6     8     6  88.0  86.0

# %%
pd.merge(df2,df5,how = 'right')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0    47    38
# 1     2   5.0   4.0     5     4
# 2    44   NaN   NaN    67    85
# 3    67   NaN   NaN     7     6
# 4     6   8.0   6.0    88    86

# %%
pd.merge(df2,df5,how = 'outer')
# Out:
#    key1  key2  key3  key4  key5
# 0     1   4.0   3.0  47.0  38.0
# 1     2   5.0   4.0   5.0   4.0
# 2     4   6.0   5.0   NaN   NaN
# 3     5   7.0   6.0   NaN   NaN
# 4     6   8.0   6.0  88.0  86.0
# 5    44   NaN   NaN  67.0  85.0
# 6    67   NaN   NaN   7.0   6.0

# %%
pd.merge(df2,df5,how = 'cross')
# Out:
#     key1_x  key2  key3  key1_y  key4  key5
# 0        1     4     3       1    47    38
# 1        1     4     3       2     5     4
# 2        1     4     3      44    67    85
# 3        1     4     3      67     7     6
# 4        1     4     3       6    88    86
# 5        2     5     4       1    47    38
# 6        2     5     4       2     5     4
# 7        2     5     4      44    67    85
# 8        2     5     4      67     7     6
# 9        2     5     4       6    88    86
# 10       4     6     5       1    47    38
# 11       4     6     5       2     5     4
# 12       4     6     5      44    67    85
# 13       4     6     5      67     7     6
# 14       4     6     5       6    88    86
# 15       5     7     6       1    47    38
# 16       5     7     6       2     5     4
# 17       5     7     6      44    67    85
# 18       5     7     6      67     7     6
# 19       5     7     6       6    88    86
# 20       6     8     6       1    47    38
# ...

# %%
df2
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
pd.merge(df2,df5,how = 'left',left_on = 'key2',right_on = 'key1')
# Out:
#    key1_x  key2  key3  key1_y  key4  key5
# 0       1     4     3     NaN   NaN   NaN
# 1       2     5     4     NaN   NaN   NaN
# 2       4     6     5     6.0  88.0  86.0
# 3       5     7     6     NaN   NaN   NaN
# 4       6     8     6     NaN   NaN   NaN

# %%
#join
df1
# Out:
# {'key1': [1, 2, 4, 5, 6], 'key2': [4, 5, 6, 7, 8], 'key3': [3, 4, 5, 6, 6]}

# %%
df2
# Out:
#    key1  key2  key3
# 0     1     4     3
# 1     2     5     4
# 2     4     6     5
# 3     5     7     6
# 4     6     8     6

# %%
df5
# Out:
#    key1  key4  key5
# 0     1    47    38
# 1     2     5     4
# 2    44    67    85
# 3    67     7     6
# 4     6    88    86

# %%
df2
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df5
# Out:
#    key1  key4  key5
# a     1    47    38
# b     2     5     4
# h    44    67    85
# i    67     7     6
# j     6    88    86

# %%
df2.join(df5,how ='left')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-4bb034569fc1> in <cell line: 1>()
# ----> 1 df2.join(df5,how ='left')
#       2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9727         5  K1  A5   B1
#    9728         """
# -> 9729         return self._join_compat(
#    9730             other,
#    9731             on=on,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9766                     validate=validate,
#    9767                 )
# -> 9768             return merge(
#    9769                 self,
#    9770                 other,
#
# ...

# %%
df1= {
    'key1':[1,2,4,5,6],
    'key2':[4,5,6,7,8],
    'key3':[3,4,5,6,6]
}

# %%
df4= {
    'key6':[1,2,45,6,67],
    'key4':[56,5,6,7,8],
    'key5':[3,56,5,6,6]
}

# %%
df5= pd.DataFrame(df4,index = ['a','b','h','i','j'])

# %%
df2
# Out:
#    key1  key2  key3
# a     1     4     3
# b     2     5     4
# c     4     6     5
# d     5     7     6
# e     6     8     6

# %%
df5
# Out:
#    key6  key4  key5
# a     1    56     3
# b     2     5    56
# h    45     6     5
# i     6     7     6
# j    67     8     6

# %%
df2.join(df5,how = 'inner')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3     1    56     3
# b     2     5     4     2     5    56

# %%
df2.join(df5,how = 'outer')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0   1.0  56.0   3.0
# b   2.0   5.0   4.0   2.0   5.0  56.0
# c   4.0   6.0   5.0   NaN   NaN   NaN
# d   5.0   7.0   6.0   NaN   NaN   NaN
# e   6.0   8.0   6.0   NaN   NaN   NaN
# h   NaN   NaN   NaN  45.0   6.0   5.0
# i   NaN   NaN   NaN   6.0   7.0   6.0
# j   NaN   NaN   NaN  67.0   8.0   6.0

# %%
df2.join(df5,how = 'left')
# Out:
#    key1  key2  key3  key6  key4  key5
# a     1     4     3   1.0  56.0   3.0
# b     2     5     4   2.0   5.0  56.0
# c     4     6     5   NaN   NaN   NaN
# d     5     7     6   NaN   NaN   NaN
# e     6     8     6   NaN   NaN   NaN

# %%
df2.join(df5,how = 'right')
# Out:
#    key1  key2  key3  key6  key4  key5
# a   1.0   4.0   3.0     1    56     3
# b   2.0   5.0   4.0     2     5    56
# h   NaN   NaN   NaN    45     6     5
# i   NaN   NaN   NaN     6     7     6
# j   NaN   NaN   NaN    67     8     6

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Fare_inr']=df['Fare'].apply(lambda x : x *90)

# %%
df['Fare_inr']
# Out:
# 0       652.500
# 1      6415.497
# 2       713.250
# 3      4779.000
# 4       724.500
#          ...
# 886    1170.000
# 887    2700.000
# 888    2110.500
# 889    2700.000
# 890     697.500
# Name: Fare_inr, Length: 891, dtype: float64

# %%
df['Name_len']=df['Name'].apply(len)

# %%
df['Name_len']
# Out:
# 0      23
# 1      51
# 2      22
# 3      44
# 4      24
#        ..
# 886    21
# 887    28
# 888    40
# 889    21
# 890    19
# Name: Name_len, Length: 891, dtype: int64

# %%
def create_flag(x):
  if x < 10:
    return "cheap"
  elif x >= 10 and x <20:
    return "medium"
  else:
    return "high"

# %%
df['Flag_Fare']=df['Fare'].apply(create_flag)

# %%
df['Flag_Fare']
# Out:
# 0       cheap
# 1        high
# 2       cheap
# 3        high
# 4       cheap
#         ...
# 886    medium
# 887      high
# 888      high
# 889      high
# 890     cheap
# Name: Flag_Fare, Length: 891, dtype: object

# %%
data = {
    "a":[100,200,13,44],
    "b":[5,5,6,7],
    "c":["pw","skill","aj","cj"]
}

# %%
df1=pd.DataFrame(data)

# %%
df1.set_index('c',inplace = True)

# %%
df1
# Out:
#        a  b
# c
# pw     1  5
# skill  2  5
# aj     3  6
# cj     4  7

# %%
df1.reset_index()
# Out:
#        c  a  b
# 0     pw  1  5
# 1  skill  2  5
# 2     aj  3  6
# 3     cj  4  7

# %%
df1.reindex(['a','bb','c','d'])
# Out:
#      a   b
# c
# a  NaN NaN
# bb NaN NaN
# c  NaN NaN
# d  NaN NaN

# %%
for i in df1.iterrows():
  print(i,"..............")
# Out:
# ('pw', a    1
# b    5
# Name: pw, dtype: int64) ..............
# ('skill', a    2
# b    5
# Name: skill, dtype: int64) ..............
# ('aj', a    3
# b    6
# Name: aj, dtype: int64) ..............
# ('cj', a    4
# b    7
# Name: cj, dtype: int64) ..............

# %%
for i in df1.items():
  print(i,"..............")
# Out:
# ('a', c
# pw       1
# skill    2
# aj       3
# cj       4
# Name: a, dtype: int64) ..............
# ('b', c
# pw       5
# skill    5
# aj       6
# cj       7
# Name: b, dtype: int64) ..............

# %%
def func_sum(x):
  return x.sum()

# %%
df1.apply(func_sum,axis = 0)
# Out:
# a    10
# b    23
# dtype: int64

# %%
df1.apply(func_sum,axis = 1)
# Out:
# c
# pw        6
# skill     7
# aj        9
# cj       11
# dtype: int64

# %%
df1.applymap(lambda x:x*2)
# Out:
#        a   b
# c
# pw     2  10
# skill  4  10
# aj     6  12
# cj     8  14

# %%
df1.sort_values(by = 'a')
# Out:
#        a  b
# c
# pw     1  5
# skill  2  5
# aj     3  6
# cj     4  7

# %%
df1
# Out:
#      a  b      c
# 0  100  5     pw
# 1  200  5  skill
# 2   13  6     aj
# 3   44  7     cj

# %%
df1.sort_values(by = 'a')
# Out:
#      a  b      c
# 2   13  6     aj
# 3   44  7     cj
# 0  100  5     pw
# 1  200  5  skill

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(by = "Fare")
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/kalki81000/python/blob/main/Untitled45.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import pandas as pd

  df = pd.read_csv("/content/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c426f622833c> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/content/titanic.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt
plt.bar(df['Sex'],df['Age'])
# Out:
# <BarContainer object of 891 artists>

# %%
plt.scatter(df['Sex'],df['Age'])

# %%
plt.plot(df['Sex'],df['Age'])

# %%
import matplotlib.pyplot as plt
plt.bar(df['Sex'],df['Age'])
plt.xticks(rotation = 45)
plt.xlabel('Sex')
plt.ylabel('Age')
plt.title('Titanic')
plt.grid()
plt.show()

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-45500c3fb5c3> in <cell line: 1>()
# ----> 1 Each_fare =df['Fare'].resample('10As').sum()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    5717         group_keys: bool = False,
#    5718     ) -> Resampler:
# -> 5719         return super().resample(
#    5720             rule=rule,
#    5721             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    8886
#    8887         axis = self._get_axis_number(axis)
# -> 8888         return get_resampler(
#    8889             cast("Series | DataFrame", self),
#    8890             freq=rule,
#
# ...

# %%
df.set_index('Order Date',inplace=True)
monthly_sales = df.resample('m').sum() #m is month basis sampling here we can check monthly data and show
plt.plot(monthly_sales)

# %%
plt.hist(df['Age'] , bins = 50
         )
# Out:
# (array([24.,  6., 14.,  3.,  7.,  8.,  6.,  3.,  7., 22., 13., 51., 40.,
#         27., 46., 24., 36., 47., 27., 35., 17., 34., 29., 11., 27.,  8.,
#         18.,  9., 17., 18.,  6., 17.,  6.,  9.,  7.,  2.,  7.,  4.,  7.,
#          4.,  3.,  1.,  0.,  2.,  3.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 0.42  ,  2.0116,  3.6032,  5.1948,  6.7864,  8.378 ,  9.9696,
#         11.5612, 13.1528, 14.7444, 16.336 , 17.9276, 19.5192, 21.1108,
#         22.7024, 24.294 , 25.8856, 27.4772, 29.0688, 30.6604, 32.252 ,
#         33.8436, 35.4352, 37.0268, 38.6184, 40.21  , 41.8016, 43.3932,
#         44.9848, 46.5764, 48.168 , 49.7596, 51.3512, 52.9428, 54.5344,
#         56.126 , 57.7176, 59.3092, 60.9008, 62.4924, 64.084 , 65.6756,
#         67.2672, 68.8588, 70.4504, 72.042 , 73.6336, 75.2252, 76.8168,
#         78.4084, 80.    ]),
#  <BarContainer object of 50 artists>)

# %%
plt.scatter(df['Sex'],df['Age'])

# %%
df.boxplot(column = 'Age' ,by = 'Sex')
plt.title("Age sex")
# Out:
# Text(0.5, 1.0, 'Age sex')

# %%
import seaborn as sns
sns.boxplot(df['Age'])
plt.show()

# %%
fig , axes = plt.subplots(2,2)
axes[0,0].plot(df['Age'],df['Fare'])
axes[0,1].scatter(df['Age'],df['Fare'])
axes[1,0].bar(df['Age'],df['Fare'])
axes[1,1].hist(df['Age'])
plt.xlabel('Age')
plt.ylabel('Fare')
plt.grid()
plt.show()

# %%
sns.distplot(df["Age"])
# Out:
# <ipython-input-32-cf0334540b62>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.barplot(x = 'Sex' , y = 'Age' ,hue = 'Fare', data = df)
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.violinplot(x = 'Fare' , y  = 'Age' , hue = 'Sex' ,data = df)
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.regplot( x = 'Fare' , y = 'Age' , data = df) # shadow part represent maximum range tolerant
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
sns.jointplot(x = 'Fare' , y = 'Age' ,data = df)

# %%
sns.heatmap(df.select_dtypes(exclude=object).corr(),annot = True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.pairplot(df[['Sex','Age','Fare','Survived']])

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(df['total_bill'])
# Out:
# <ipython-input-5-08d2c75decc2>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.barplot(x ='total_bill' , y = 'tip' ,hue = 'sex',data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(df['total_bill'] , df['tip'])

# %%
sns.scatterplot(x = 'total_bill' , y = 'tip' , hue = 'smoker' ,data = df)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
